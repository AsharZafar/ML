# %% [markdown]
# <a href="https://colab.research.google.com/github/AsharZafar/ML/blob/main/gradient%20decent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# !pip install numpy

# %%
X=np.array([1,2,3,4,5])
Y=np.array([5,7,9,11,13])

# %%
from re import M
def gradient_decent(X,Y):
  m_curr=b_curr=0
  iterations=1000
  learning_rate=0.08
  n=len(X)

  for i in range(iterations):
    y_predicted= m_curr * X +b_curr
    cost=(1/n) * sum([val**2 for val in (Y-y_predicted)])
    md=-(2/n)*sum(X * (Y-y_predicted))
    bd=-(2/n)*sum(Y-y_predicted)
    m_curr=m_curr-learning_rate*md
    b_curr=b_curr-learning_rate*bd
    print("m={},b={},cost{},iterations{}".format(m_curr,b_curr,cost,i+1))
gradient_decent(X,Y)
# Out:
# m=4.96,b=1.44,cost89.0,iterations1
# m=0.4991999999999983,b=0.26879999999999993,cost71.10560000000002,iterations2
# m=4.451584000000002,b=1.426176000000001,cost56.8297702400001,iterations3
# m=0.892231679999997,b=0.5012275199999995,cost45.43965675929613,iterations4
# m=4.041314713600002,b=1.432759910400001,cost36.35088701894832,iterations5
# m=1.2008760606719973,b=0.7036872622079998,cost29.097483330142282,iterations6
# m=3.7095643080294423,b=1.4546767911321612,cost23.307872849944438,iterations7
# m=1.4424862661541864,b=0.881337636696883,cost18.685758762535738,iterations8
# m=3.4406683721083144,b=1.4879302070713722,cost14.994867596913156,iterations9
# m=1.6308855378034224,b=1.0383405553279617,cost12.046787238456794,iterations10
# m=3.2221235247119777,b=1.5293810083298451,cost9.691269350698109,iterations11
# m=1.7770832372205707,b=1.1780607551353204,cost7.8084968312098315,iterations12
# m=3.0439475772474127,b=1.5765710804477953,cost6.302918117062937,iterations13
# ...

# %%
import numpy as np

def gradient_descent(X, Y):
    m_curr = b_curr = 0
    iterations = 100
    learning_rate = 0.001
    n = len(X)

    for i in range(iterations):
        y_predicted = m_curr * X + b_curr
        md = -(2/n) * np.sum(X * (Y - y_predicted))  # Element-wise multiplication
        bd = -(2/n) * np.sum(Y - y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print("m={}, b={}, iteration={}".format(m_curr, b_curr, i+1))

# Sample data
X = np.array([1, 2, 3, 4, 5])
Y = np.array([5, 7, 9, 11, 13])

gradient_descent(X, Y)
# Out:
# m=0.062, b=0.018000000000000002, iteration=1
# m=0.122528, b=0.035592000000000006, iteration=2
# m=0.181618832, b=0.052785648000000004, iteration=3
# m=0.239306503808, b=0.069590363712, iteration=4
# m=0.29562421854195203, b=0.086015343961728, iteration=5
# m=0.35060439367025875, b=0.10206956796255283, iteration=6
# m=0.40427867960173774, b=0.11776180246460617, iteration=7
# m=0.4566779778357119, b=0.13310060678206653, iteration=8
# m=0.5078324586826338, b=0.14809433770148814, iteration=9
# m=0.5577715785654069, b=0.16275115427398937, iteration=10
# m=0.606524096911324, b=0.17707902249404894, iteration=11
# m=0.6541180926443106, b=0.1910857198675929, iteration=12
# m=0.7005809802869303, b=0.20477883987199186, iteration=13
# m=0.7459395256813859, b=0.2181657963105263, iteration=14
# m=0.7902198613385323, b=0.23125382756381693, iteration=15
# m=0.8334475014237017, b=0.2440500007406581, iteration=16
# m=0.8756473563879363, b=0.25656121573063456, iteration=17
# ...

# %%
import numpy as np
import pandas as pd
# !git clone "https://github.com/AsharZafar/ML.git"
df= pd.read_csv("/content/ML/gradient decent/test_scores.csv")
# Out:
# fatal: destination path 'ML' already exists and is not an empty directory.

# %%
df.head()
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83

# %%
X1=np.array([df.math])
Y1=np.array([df.cs])

# %%
def gradient_decent(X1,Y1):
  m_curr=b_curr=0
  iterations=10
  learning_rate=0.001
  n=len(X1)

  for i in range(iterations):
    y_predicted= m_curr * X1 +b_curr
    cost=(1/n) * sum([val**2 for val in (Y1-y_predicted)])
    md=-(2/n)*sum(X1 * (Y1-y_predicted))
    bd=-(2/n)*sum(Y1-y_predicted)
    m_curr=m_curr-learning_rate*md
    b_curr=b_curr-learning_rate*bd
    print("m={},b={},cost{},iterations{}".format(m_curr,b_curr,cost,i+1))
gradient_decent(X1,Y1)
# Out:
# m=[18.032  7.616 14.256 11.2   13.28   5.096  8.58   2.1    8.976  9.782],b=[0.196 0.136 0.162 0.16  0.166 0.104 0.132 0.06  0.136 0.146],cost[9604. 4624. 6561. 6400. 6889. 2704. 4356.  900. 4624. 5329.],iterations1
# m=[-269.21776   -32.550784 -192.31344   -87.3824   -143.45056   -14.289184
#   -55.35816    -0.9492    -60.264864  -68.27836 ],b=[-2.92628  -0.581264 -2.18538  -1.24832  -1.793132 -0.291616 -0.851664
#  -0.02712  -0.913104 -1.01908 ],cost[2.43715810e+06 1.28616911e+05 1.37754822e+06 4.95841306e+05
#  9.59549548e+05 3.91280049e+04 2.41898716e+05 1.89747360e+03
#  2.75154801e+05 3.39352852e+05],iterations2
# m=[4.30667092e+03 1.79288835e+02 2.80087775e+03 7.80339885e+02
#  1.70628351e+03 5.94520559e+01 4.21109008e+02 3.47823840e+00
#  4.73859161e+02 5.54643313e+02],b=[46.8116404   3.20158634 31.8281562  11.14771264 21.32854386  1.21330726
#   6.47860013  0.09937824  7.17968426  8.2782584 ],cost[6.18465181e+08 3.57748917e+06 2.89230161e+08 3.84154063e+07
# ...
